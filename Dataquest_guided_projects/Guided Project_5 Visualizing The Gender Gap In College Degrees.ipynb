# %% [markdown]
# The first cell of code was provided by Dataquest as a basis for this guided project. I learned the methods used in this project in previous exercise I have done on Dataquest.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']

fig = plt.figure(figsize=(18, 3))

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()

# %%
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

fig = plt.figure(figsize = (20, 20))

#sets the range between 0 and 18, with 18 not inclusive, by steps of 3. 
for x in range(0, 18, 3):
    stemindex = int(x/3)
    ax = fig.add_subplot(6, 3, x + 1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[stemindex]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[stemindex]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[stemindex])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    if stemindex == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif stemindex == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')

        
for x in range(1, 16, 3):
    libartindex = int((x-1)/3) 
    ax = fig.add_subplot(6, 3, x + 1)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[libartindex]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[libartindex]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[libartindex])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    if libartindex == 0:
        ax.text(2005, 20, 'Men')
        ax.text(2002, 75, 'Women')
    

for x in range(3,21,3):
    otherindex = int((x/3)-1) 
    ax = fig.add_subplot(6, 3, x)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[otherindex]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[otherindex]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[otherindex])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    if otherindex == 0:
        ax.text(2006, 5, 'Men')
        ax.text(2004, 90, 'Women')
    elif otherindex == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2005, 35, 'Women')

# %%
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

fig = plt.figure(figsize = (20, 20))

for x in range(0, 18, 3):
    stemindex = int(x/3)
    ax = fig.add_subplot(6, 3, x + 1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[stemindex]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[stemindex]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[stemindex])
    #removes the bottom labels from graphs (year).
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    if stemindex == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif stemindex == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        ax.tick_params(labelbottom="on")

        
for x in range(1, 16, 3):
    libartindex = int((x-1)/3) 
    ax = fig.add_subplot(6, 3, x + 1)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[libartindex]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[libartindex]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[libartindex])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    if libartindex == 0:
        ax.text(2005, 20, 'Men')
        ax.text(2002, 75, 'Women')
    elif libartindex == 4:
        ax.tick_params(labelbottom='on')
    

for x in range(3,21,3):
    otherindex = int((x/3)-1) 
    ax = fig.add_subplot(6, 3, x)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[otherindex]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[otherindex]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["bottom"].set_visible(False)
    ax.spines["top"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[otherindex])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    if otherindex == 0:
        ax.text(2006, 5, 'Men')
        ax.text(2004, 90, 'Women')
    elif otherindex == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2005, 35, 'Women')
        ax.tick_params(labelbottom='on')

# %%
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

fig = plt.figure(figsize = (20, 20))

for x in range(0, 18, 3):
    stemindex = int(x/3)
    ax = fig.add_subplot(6, 3, x + 1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[stemindex]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[stemindex]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[stemindex])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    #only shows y ticks at 0 and 100
    ax.set_yticks([0,100])
    if stemindex == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif stemindex == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        ax.tick_params(labelbottom="on")
        
for x in range(1, 16, 3):
    libartindex = int((x-1)/3) 
    ax = fig.add_subplot(6, 3, x + 1)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[libartindex]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[libartindex]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[libartindex])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax.set_yticks([0,100])
    if libartindex == 0:
        ax.text(2005, 20, 'Men')
        ax.text(2002, 75, 'Women')
    elif libartindex == 4:
        ax.tick_params(labelbottom='on')
    

for x in range(3,21,3):
    otherindex = int((x/3)-1) 
    ax = fig.add_subplot(6, 3, x)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[otherindex]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[otherindex]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["bottom"].set_visible(False)
    ax.spines["top"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[otherindex])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax.set_yticks([0,100])
    if otherindex == 0:
        ax.text(2006, 5, 'Men')
        ax.text(2004, 90, 'Women')
    elif otherindex == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2005, 35, 'Women')
        ax.tick_params(labelbottom='on')

# %%
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

fig = plt.figure(figsize = (20, 20))

for x in range(0, 18, 3):
    stemindex = int(x/3)
    ax = fig.add_subplot(6, 3, x + 1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[stemindex]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[stemindex]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[stemindex])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    if stemindex == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif stemindex == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        ax.tick_params(labelbottom="on")
        
for x in range(1, 16, 3):
    libartindex = int((x-1)/3) 
    ax = fig.add_subplot(6, 3, x + 1)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[libartindex]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[libartindex]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[libartindex])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    if libartindex == 0:
        ax.text(2005, 20, 'Men')
        ax.text(2002, 75, 'Women')
    elif libartindex == 4:
        ax.tick_params(labelbottom='on')
    

for x in range(3,21,3):
    otherindex = int((x/3)-1) 
    ax = fig.add_subplot(6, 3, x)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[otherindex]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[otherindex]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["bottom"].set_visible(False)
    ax.spines["top"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[otherindex])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    if otherindex == 0:
        ax.text(2006, 5, 'Men')
        ax.text(2004, 90, 'Women')
    elif otherindex == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2005, 35, 'Women')
        ax.tick_params(labelbottom='on')

# %%
plt.savefig('gender_degrees.png')
